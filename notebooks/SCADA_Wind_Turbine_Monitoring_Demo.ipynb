# %%
# !git clone https://github.com/leahmarymathew/SCADA-Wind-Monitoring.git
# %cd SCADA-Wind-Monitoring
# !pip install -r requirements.txt

# %%
# !python src/preprocess.py
# !python src/train_model.py
# !python src/explain_shap.py
